# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df_falhas = pd.read_csv('/home/linguica/isabelle/sprint3/sprint3v2/FALHAS_PREDICT.csv')

# %%
import pandas as pd

# Definir o caminho base
BASE_PATH = '/home/linguica/isabelle/sprint3/sprint3v2/STATUS_PREDICTOR_ANO.xlsx'
column_names = ['KNR', 'STATUS', 'DATA']  # Nomes das colunas a serem usadas

def read_excel_sheets(file_path):
    # Carregar o arquivo Excel
    excel_data = pd.ExcelFile(f'{BASE_PATH}{file_path}')
    
    df_list = []
    
    for i, sheet in enumerate(excel_data.sheet_names):
        print(f'Processing sheet {sheet}')
        # A primeira aba tem o cabeçalho correto
        if i == 0:
            df = pd.read_excel(excel_data, sheet_name=sheet, header=0)
        else:
            # Nas outras abas, ler os dados sem cabeçalho
            df = pd.read_excel(excel_data, sheet_name=sheet, header=None)
            # Renomear colunas para 'Unnamed: 1', 'Unnamed: 2', etc., e limpar
            df = pd.DataFrame(df[[1, 2, 3]])  # Selecionar as colunas certas
            df.columns = column_names  # Atribuir os nomes das colunas
            
        df_list.append(df)
        print(f'Processed {df.shape[0]} rows')
    
    print(f'Processed {len(df_list)} sheets')
    return pd.concat(df_list, ignore_index=True)

# Usar a função
df_tst = read_excel_sheets("")
print(df_tst.head())
# Out:
# /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Processing sheet Relatório 1
# Processed 1048574 rows
# Processing sheet Relatório 1(1)
# Processed 1048575 rows
# Processing sheet Relatório 1(2)
# Processed 1048575 rows
# Processing sheet Relatório 1(3)
# Processed 1048575 rows
# Processing sheet Relatório 1(4)
# Processed 153682 rows
# Processed 5 sheets
#    Unnamed: 0    Unnamed: 1 Unnamed: 2           Unnamed: 3  KNR STATUS DATA
# 0         NaN           KNR     STATUS                 DATA  NaN    NaN  NaT
# 1         NaN  2023-2016173       G620  2023-06-06 07:50:27  NaN    NaN  NaT
# 2         NaN  2023-2016173       M620  2023-06-06 07:50:27  NaN    NaN  NaT
# 3         NaN  2023-2026032       G620  2023-06-20 17:35:51  NaN    NaN  NaT
# 4         NaN  2023-2026032       M620  2023-06-20 17:35:51  NaN    NaN  NaT

# %%
df_tst = df_tst[df_tst["STATUS"].isnull()==False]
df_tst.shape
# Out:
# (3299407, 7)

# %%
df_tst.head()
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           KNR STATUS  \
# 1048574         NaN        NaN        NaN        NaN  2023-4026002   R600
# 1048575         NaN        NaN        NaN        NaN  2023-4026002   R700
# 1048576         NaN        NaN        NaN        NaN  2023-4026002   R725
# 1048577         NaN        NaN        NaN        NaN  2023-4026002   R750
# 1048578         NaN        NaN        NaN        NaN  2023-4026002   R755
#
#                        DATA
# 1048574 2023-09-29 07:14:44
# 1048575 2023-09-29 07:38:47
# 1048576 2023-09-29 07:53:00
# 1048577 2023-09-29 08:16:23
# 1048578 2023-09-29 08:17:01

# %%
df_tst = df_tst.drop(columns=["Unnamed: 0", "Unnamed: 1", "Unnamed: 2", "Unnamed: 3"])

# %%
df_tst.head()
# Out:
#                   KNR STATUS                DATA
# 1048574  2023-4026002   R600 2023-09-29 07:14:44
# 1048575  2023-4026002   R700 2023-09-29 07:38:47
# 1048576  2023-4026002   R725 2023-09-29 07:53:00
# 1048577  2023-4026002   R750 2023-09-29 08:16:23
# 1048578  2023-4026002   R755 2023-09-29 08:17:01

# %%
df_tst = df_tst.reset_index()

# %%
df_tst.columns
# Out:
# Index(['index', 'KNR', 'STATUS', 'DATA'], dtype='object')

# %%
df_tst.head()
# Out:
#      index           KNR STATUS                DATA
# 0  1048574  2023-4026002   R600 2023-09-29 07:14:44
# 1  1048575  2023-4026002   R700 2023-09-29 07:38:47
# 2  1048576  2023-4026002   R725 2023-09-29 07:53:00
# 3  1048577  2023-4026002   R750 2023-09-29 08:16:23
# 4  1048578  2023-4026002   R755 2023-09-29 08:17:01

# %%
df_tst.drop(columns=['index'])
# Out:
#                   KNR STATUS                DATA
# 0        2023-4026002   R600 2023-09-29 07:14:44
# 1        2023-4026002   R700 2023-09-29 07:38:47
# 2        2023-4026002   R725 2023-09-29 07:53:00
# 3        2023-4026002   R750 2023-09-29 08:16:23
# 4        2023-4026002   R755 2023-09-29 08:17:01
# ...               ...    ...                 ...
# 3299402  2024-2976013   L66A 2024-06-04 08:27:58
# 3299403  2024-2976013   L662 2024-06-04 08:28:35
# 3299404  2024-2976013   L700 2024-06-04 08:44:57
# 3299405  2024-2976013   I100 2024-06-04 08:47:11
# 3299406  2024-2976013   L800 2024-06-04 08:47:11
#
# [3299407 rows x 3 columns]

# %%
df_tst.shape
# Out:
# (3299407, 4)

# %%
n = 0
arr = list(set(df_falhas["KNR"]))
arrL = list(set(df_tst["KNR"]))
for k in arr:
    if k in arrL:
        n+=1

# %%
print(n)
# Out:
# 35674

# %%
# Lista de valores que você quer filtrar
status_filtrados = ['R750', 'L540', 'G700', 'M600', 'M700']

# Filtrando o DataFrame e sobrescrevendo ele mesmo
df_tst = df_tst[df_tst['STATUS'].isin(status_filtrados)]

# Exibindo o resultado
print(df_tst)
# Out:
#            index           KNR STATUS                DATA
# 3        1048577  2023-4026002   R750 2023-09-29 08:16:23
# 18       1048592  2023-4026002   L540 2023-10-02 09:20:28
# 37       1048611  2023-4026002   G700 2023-10-03 10:46:02
# 39       1048613  2023-4026002   M600 2023-10-03 12:21:54
# 43       1048617  2023-4026002   M700 2023-10-03 13:31:36
# ...          ...           ...    ...                 ...
# 3299281  4347855  2024-2976010   R750 2024-05-24 16:02:47
# 3299298  4347872  2024-2976010   L540 2024-06-05 21:08:10
# 3299313  4347887  2024-2976011   R750 2024-05-22 15:37:00
# 3299345  4347919  2024-2976012   R750 2024-05-23 09:03:19
# 3299381  4347955  2024-2976013   R750 2024-05-21 14:36:39
#
# [294641 rows x 4 columns]

# %%
status_per_knr = df_tst.groupby('KNR')['STATUS'].unique().reset_index()

status_per_knr
# Out:
#                 KNR                          STATUS
# 0      2023-4026002  [R750, L540, G700, M600, M700]
# 1      2023-4026003  [R750, L540, G700, M600, M700]
# 2      2023-4026004  [R750, L540, G700, M600, M700]
# 3      2023-4026005  [R750, L540, G700, M600, M700]
# 4      2023-4026006  [R750, L540, G700, M600, M700]
# ...             ...                             ...
# 60905  2024-2976009                    [R750, L540]
# 60906  2024-2976010                    [R750, L540]
# 60907  2024-2976011                          [R750]
# 60908  2024-2976012                          [R750]
# 60909  2024-2976013                          [R750]
#
# [60910 rows x 2 columns]

# %%
# Supondo que a coluna de data se chame 'DATA'
df_tst['DATA'] = pd.to_datetime(df_tst['DATA'])

# Exibindo o resultado
print(df_tst.dtypes)  # Para confirmar que a coluna foi convertida para datetime
# Out:
# index              int64
# KNR               object
# STATUS            object
# DATA      datetime64[ns]
# dtype: object

# %%
# # Supondo que 'KNR' seja a coluna de IDs e 'STATUS' a coluna dos status
# status_necessarios = ['R750', 'L540', 'G700', 'M600', 'M700']

# # Filtrando o DataFrame para os status que você quer
# df_filtrado = df_tst[df_tst['STATUS'].isin(status_necessarios)]

# # Agrupando por KNR e verificando se cada KNR contém todos os status necessários
# knr_completos = df_filtrado.groupby('KNR')['STATUS'].nunique()

# # Filtrando para encontrar os KNRs que têm exatamente a quantidade de status que você precisa
# knr_validos = knr_completos[knr_completos == len(status_necessarios)]

# # Contando quantos KNRs têm todos os status
# quantidade_knr = knr_validos.count()

# print(f"Quantidade de KNRs com todos os status necessários: {quantidade_knr}")

# %%
# Defina os status necessários
status_necessarios = ['R750', 'L540', 'G700', 'M600', 'M700']

# Filtrando o DataFrame para os status que você quer
df_filtrado = df_tst[df_tst['STATUS'].isin(status_necessarios)]

# Criar um DataFrame com KNR e STATUS para indicar presença
df_filtrado['Presença'] = 1

# Usar pivot_table para transformar STATUS em colunas e KNR em linhas
df_pivot = df_filtrado.pivot_table(index='KNR', columns='STATUS', values='Presença', aggfunc='max', fill_value=0)

# Garantir que todas as colunas necessárias estão presentes (incluindo aquelas que não têm dados)
df_pivot = df_pivot.reindex(columns=status_necessarios, fill_value=0)

# Resetar o índice para tornar KNR uma coluna normal novamente
df_pivot.reset_index(inplace=True)

# Exibir o resultado
print(df_pivot)
# Out:
# STATUS           KNR  R750  L540  G700  M600  M700
# 0       2023-4026002     1     1     1     1     1
# 1       2023-4026003     1     1     1     1     1
# 2       2023-4026004     1     1     1     1     1
# 3       2023-4026005     1     1     1     1     1
# 4       2023-4026006     1     1     1     1     1
# ...              ...   ...   ...   ...   ...   ...
# 60905   2024-2976009     1     1     0     0     0
# 60906   2024-2976010     1     1     0     0     0
# 60907   2024-2976011     1     0     0     0     0
# 60908   2024-2976012     1     0     0     0     0
# 60909   2024-2976013     1     0     0     0     0
#
# [60910 rows x 6 columns]

# %%
# Garantir que DATA esteja no formato datetime
df_tst['DATA'] = pd.to_datetime(df_tst['DATA'])

# %%
# Ordenar o DataFrame por KNR e DATA
df_tst.sort_values(by=['KNR', 'DATA'], inplace=True)

# %%
# Definir a ordem dos status
status_necessarios = ['R750', 'L540', 'G700', 'M600', 'M700']

# Criar colunas para armazenar o tempo de cada status
for status in status_necessarios:
    df_tst[f'Tempo{status}'] = pd.Timedelta(seconds=0)

# %%
# Função para calcular o tempo entre status
def calcular_tempo_por_status(df):
    for i in range(len(status_necessarios) - 1):
        status_atual = status_necessarios[i]
        proximo_status = status_necessarios[i + 1]
        
        # Filtrar o DataFrame para o status atual e o próximo status
        df_status_atual = df[df['STATUS'] == status_atual]
        df_proximo_status = df[df['STATUS'] == proximo_status]
        
        # Para cada linha no status atual, buscar a próxima ocorrência no próximo status
        for idx, row in df_status_atual.iterrows():
            # Encontrar a próxima linha no próximo status para o mesmo KNR
            proxima_linha = df_proximo_status[df_proximo_status['KNR'] == row['KNR']]
            
            if not proxima_linha.empty:
                # Calcular a diferença de tempo entre o status atual e o próximo status
                tempo_gasto = proxima_linha['DATA'].iloc[0] - row['DATA']
                df.at[idx, f'Tempo{status_atual}'] = tempo_gasto

    return df

# %%
# Aplicar a função para calcular o tempo para cada KNR
df_tst = df_tst.groupby('KNR', group_keys=False).apply(calcular_tempo_por_status)

# Exibir o resultado
df_tst.head()
# Out:
# /tmp/ipykernel_6816/1833544416.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tst = df_tst.groupby('KNR', group_keys=False).apply(calcular_tempo_por_status)
#       index           KNR STATUS                DATA       TempoR750  \
# 3   1048577  2023-4026002   R750 2023-09-29 08:16:23 3 days 01:04:05
# 18  1048592  2023-4026002   L540 2023-10-02 09:20:28 0 days 00:00:00
# 37  1048611  2023-4026002   G700 2023-10-03 10:46:02 0 days 00:00:00
# 39  1048613  2023-4026002   M600 2023-10-03 12:21:54 0 days 00:00:00
# 43  1048617  2023-4026002   M700 2023-10-03 13:31:36 0 days 00:00:00
#
#          TempoL540       TempoG700       TempoM600 TempoM700
# 3  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00    0 days
# 18 1 days 01:25:34 0 days 00:00:00 0 days 00:00:00    0 days
# 37 0 days 00:00:00 0 days 01:35:52 0 days 00:00:00    0 days
# 39 0 days 00:00:00 0 days 00:00:00 0 days 01:09:42    0 days
# 43 0 days 00:00:00 0 days 00:00:00 0 days 00:00:00    0 days

# %%
df_tst.fillna(pd.Timedelta(seconds=0), inplace=True)

# %%
df_tst.head()
# Out:
#       index           KNR STATUS                DATA       TempoR750  \
# 3   1048577  2023-4026002   R750 2023-09-29 08:16:23 3 days 01:04:05
# 18  1048592  2023-4026002   L540 2023-10-02 09:20:28 0 days 00:00:00
# 37  1048611  2023-4026002   G700 2023-10-03 10:46:02 0 days 00:00:00
# 39  1048613  2023-4026002   M600 2023-10-03 12:21:54 0 days 00:00:00
# 43  1048617  2023-4026002   M700 2023-10-03 13:31:36 0 days 00:00:00
#
#          TempoL540       TempoG700       TempoM600 TempoM700
# 3  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00    0 days
# 18 1 days 01:25:34 0 days 00:00:00 0 days 00:00:00    0 days
# 37 0 days 00:00:00 0 days 01:35:52 0 days 00:00:00    0 days
# 39 0 days 00:00:00 0 days 00:00:00 0 days 01:09:42    0 days
# 43 0 days 00:00:00 0 days 00:00:00 0 days 00:00:00    0 days

# %%
# Defina os status necessários
status_necessarios = ['R750', 'L540', 'G700', 'M600', 'M700']

# Filtrar o DataFrame para os status que você quer
df_filtrado = df_tst[df_tst['STATUS'].isin(status_necessarios)]

# Criar uma coluna de presença
df_filtrado['Presença'] = 1

# Criar uma tabela dinâmica para cada status
df_status_columns = df_filtrado.pivot_table(index='KNR', columns='STATUS', values='Presença', aggfunc='max', fill_value=0)

# Garantir que todas as colunas necessárias estejam presentes (incluindo aquelas que não têm dados)
df_status_columns = df_status_columns.reindex(columns=status_necessarios, fill_value=0)

# Resetar o índice para tornar KNR uma coluna normal novamente
df_status_columns.reset_index(inplace=True)

# Mesclar com o DataFrame original
df_tst = df_tst.merge(df_status_columns, on='KNR', how='left')

df_tst.head()
# Out:
#      index           KNR STATUS                DATA       TempoR750  \
# 0  1048577  2023-4026002   R750 2023-09-29 08:16:23 3 days 01:04:05
# 1  1048592  2023-4026002   L540 2023-10-02 09:20:28 0 days 00:00:00
# 2  1048611  2023-4026002   G700 2023-10-03 10:46:02 0 days 00:00:00
# 3  1048613  2023-4026002   M600 2023-10-03 12:21:54 0 days 00:00:00
# 4  1048617  2023-4026002   M700 2023-10-03 13:31:36 0 days 00:00:00
#
#         TempoL540       TempoG700       TempoM600 TempoM700  R750  L540  G700  \
# 0 0 days 00:00:00 0 days 00:00:00 0 days 00:00:00    0 days     1     1     1
# 1 1 days 01:25:34 0 days 00:00:00 0 days 00:00:00    0 days     1     1     1
# 2 0 days 00:00:00 0 days 01:35:52 0 days 00:00:00    0 days     1     1     1
# 3 0 days 00:00:00 0 days 00:00:00 0 days 01:09:42    0 days     1     1     1
# 4 0 days 00:00:00 0 days 00:00:00 0 days 00:00:00    0 days     1     1     1
#
#    M600  M700
# 0     1     1
# 1     1     1
# 2     1     1
# 3     1     1
# 4     1     1

# %%
df_tst.columns
# Out:
# Index(['index', 'KNR', 'STATUS', 'DATA', 'TempoR750', 'TempoL540', 'TempoG700',
#        'TempoM600', 'TempoM700', 'R750', 'L540', 'G700', 'M600', 'M700'],
#       dtype='object')

# %%
df_tst.drop(columns=['STATUS', 'DATA', 'index'])
# Out:
#                  KNR        TempoR750       TempoL540       TempoG700  \
# 0       2023-4026002  3 days 01:04:05 0 days 00:00:00 0 days 00:00:00
# 1       2023-4026002  0 days 00:00:00 1 days 01:25:34 0 days 00:00:00
# 2       2023-4026002  0 days 00:00:00 0 days 00:00:00 0 days 01:35:52
# 3       2023-4026002  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00
# 4       2023-4026002  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00
# ...              ...              ...             ...             ...
# 294636  2024-2976010 12 days 05:05:23 0 days 00:00:00 0 days 00:00:00
# 294637  2024-2976010  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00
# 294638  2024-2976011  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00
# 294639  2024-2976012  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00
# 294640  2024-2976013  0 days 00:00:00 0 days 00:00:00 0 days 00:00:00
#
#              TempoM600 TempoM700  R750  L540  G700  M600  M700
# 0      0 days 00:00:00    0 days     1     1     1     1     1
# 1      0 days 00:00:00    0 days     1     1     1     1     1
# 2      0 days 00:00:00    0 days     1     1     1     1     1
# 3      0 days 01:09:42    0 days     1     1     1     1     1
# 4      0 days 00:00:00    0 days     1     1     1     1     1
# ...                ...       ...   ...   ...   ...   ...   ...
# 294636 0 days 00:00:00    0 days     1     1     0     0     0
# 294637 0 days 00:00:00    0 days     1     1     0     0     0
# 294638 0 days 00:00:00    0 days     1     0     0     0     0
# 294639 0 days 00:00:00    0 days     1     0     0     0     0
# 294640 0 days 00:00:00    0 days     1     0     0     0     0
#
# [294641 rows x 11 columns]

# %% [markdown]
# # AINDA TO TESTANDO DPS DISSO

# %%
# Especificar o caminho e nome do arquivo CSV onde deseja salvar
df_tst.to_csv('statusTratadoV2.csv', index=False)

# %%
df_monstro = pd.read_csv('/home/linguica/isabelle/sprint3/sprint3v2/df_combined_final_monstro.csv')

# %%
df_monstro.head()
# Out:
#    Unnamed: 0           KNR  Nvezes1  Nvezes2  Nvezes718       SomaTempo1  \
# 0           0  2023-2016173      0.0     16.0       40.0  0 days 00:00:00
# 1           1  2023-2026098      0.0     20.0       90.0  0 days 00:00:00
# 2           2  2023-2026162      0.0     20.0       50.0  0 days 00:00:00
# 3           3  2023-2026175      0.0     14.0       49.0  0 days 00:00:00
# 4           4  2023-2026215      0.0     26.0       91.0  0 days 00:00:00
#
#         SomaTempo2      SomaTempo718 Intervalo_SomaTempo1  \
# 0  0 days 00:00:40   0 days 10:15:26                  NaN
# 1  0 days 00:00:03   0 days 09:38:18                  NaN
# 2  0 days 00:00:10   0 days 02:15:14                  NaN
# 3  0 days 00:00:18   2 days 06:06:06                  NaN
# 4  0 days 00:00:20  12 days 20:23:08                  NaN
#
#   Intervalo_SomaTempo2 Intervalo_SomaTempo718  TemFalhaRod
# 0               <1 dia                 <1 dia            0
# 1               <1 dia                 <1 dia            1
# 2               <1 dia                 <1 dia            0
# 3               <1 dia       1 dia - 1 semana            0
# 4               <1 dia       1 semana - 1 mês            0

# %%
df_status = pd.read_csv('/home/linguica/isabelle/sprint3/sprint3v2/statusTratadoV2.csv')

# %%
# Realizar o merge das tabelas df_status e df_monstro com base na coluna 'KNR'
# Mantendo apenas os KNRs presentes em df_status
df_merged = pd.merge(df_status, df_monstro, on='KNR', how='left')

# Opcional: Se quiser remover as linhas onde não houve correspondência em df_monstro (linhas com NaN)
df_merged = df_merged.dropna()

# Exibir as primeiras linhas do DataFrame resultante
print(df_merged.head())
# Out:
#      index           KNR STATUS                 DATA        TempoR750  \
# 0  1048577  2023-4026002   R750  2023-09-29 08:16:23  3 days 01:04:05
# 1  1048592  2023-4026002   L540  2023-10-02 09:20:28  0 days 00:00:00
# 2  1048611  2023-4026002   G700  2023-10-03 10:46:02  0 days 00:00:00
# 3  1048613  2023-4026002   M600  2023-10-03 12:21:54  0 days 00:00:00
# 4  1048617  2023-4026002   M700  2023-10-03 13:31:36  0 days 00:00:00
#
#          TempoL540        TempoG700        TempoM600 TempoM700  R750  ...  \
# 0  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1  ...
# 1  1 days 01:25:34  0 days 00:00:00  0 days 00:00:00    0 days     1  ...
# 2  0 days 00:00:00  0 days 01:35:52  0 days 00:00:00    0 days     1  ...
# 3  0 days 00:00:00  0 days 00:00:00  0 days 01:09:42    0 days     1  ...
# 4  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1  ...
#
#    Nvezes1  Nvezes2  Nvezes718       SomaTempo1       SomaTempo2  \
# 0     18.0    452.0       14.0  0 days 02:25:48  8 days 10:37:42
# 1     18.0    452.0       14.0  0 days 02:25:48  8 days 10:37:42
# 2     18.0    452.0       14.0  0 days 02:25:48  8 days 10:37:42
# 3     18.0    452.0       14.0  0 days 02:25:48  8 days 10:37:42
# 4     18.0    452.0       14.0  0 days 02:25:48  8 days 10:37:42
#
#       SomaTempo718  Intervalo_SomaTempo1  Intervalo_SomaTempo2  \
# 0  0 days 10:36:04                <1 dia      1 semana - 1 mês
# 1  0 days 10:36:04                <1 dia      1 semana - 1 mês
# 2  0 days 10:36:04                <1 dia      1 semana - 1 mês
# 3  0 days 10:36:04                <1 dia      1 semana - 1 mês
# 4  0 days 10:36:04                <1 dia      1 semana - 1 mês
#
#   Intervalo_SomaTempo718 TemFalhaRod
# 0                 <1 dia         0.0
# 1                 <1 dia         0.0
# 2                 <1 dia         0.0
# 3                 <1 dia         0.0
# 4                 <1 dia         0.0
#
# [5 rows x 25 columns]

# %%
df_merged
# Out:
#           index           KNR STATUS                 DATA        TempoR750  \
# 0       1048577  2023-4026002   R750  2023-09-29 08:16:23  3 days 01:04:05
# 1       1048592  2023-4026002   L540  2023-10-02 09:20:28  0 days 00:00:00
# 2       1048611  2023-4026002   G700  2023-10-03 10:46:02  0 days 00:00:00
# 3       1048613  2023-4026002   M600  2023-10-03 12:21:54  0 days 00:00:00
# 4       1048617  2023-4026002   M700  2023-10-03 13:31:36  0 days 00:00:00
# ...         ...           ...    ...                  ...              ...
# 218462  3433027  2024-1916086   M700  2024-04-05 12:05:17  0 days 00:00:00
# 231227  3578556  2024-2016184   R750  2024-03-21 17:53:25  0 days 00:00:00
# 231228  3578595  2024-2016184   G700  2024-04-10 14:15:40  0 days 00:00:00
# 231229  3578600  2024-2016184   M600  2024-04-15 11:48:32  0 days 00:00:00
# 231230  3578602  2024-2016184   M700  2024-04-15 11:48:33  0 days 00:00:00
#
#               TempoL540        TempoG700        TempoM600 TempoM700  R750  \
# 0       0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# 1       1 days 01:25:34  0 days 00:00:00  0 days 00:00:00    0 days     1
# 2       0 days 00:00:00  0 days 01:35:52  0 days 00:00:00    0 days     1
# 3       0 days 00:00:00  0 days 00:00:00  0 days 01:09:42    0 days     1
# 4       0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# ...                 ...              ...              ...       ...   ...
# 218462  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# 231227  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# 231228  0 days 00:00:00  4 days 21:32:52  0 days 00:00:00    0 days     1
# 231229  0 days 00:00:00  0 days 00:00:00  0 days 00:00:01    0 days     1
# 231230  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
#
#         ...  Nvezes1  Nvezes2  Nvezes718       SomaTempo1        SomaTempo2  \
# 0       ...     18.0    452.0       14.0  0 days 02:25:48   8 days 10:37:42
# 1       ...     18.0    452.0       14.0  0 days 02:25:48   8 days 10:37:42
# 2       ...     18.0    452.0       14.0  0 days 02:25:48   8 days 10:37:42
# 3       ...     18.0    452.0       14.0  0 days 02:25:48   8 days 10:37:42
# 4       ...     18.0    452.0       14.0  0 days 02:25:48   8 days 10:37:42
# ...     ...      ...      ...        ...              ...               ...
# 218462  ...     54.0   2106.0      198.0  0 days 02:48:40  64 days 14:17:28
# 231227  ...     48.0   1832.0       88.0  0 days 01:19:55  21 days 22:01:43
# 231228  ...     48.0   1832.0       88.0  0 days 01:19:55  21 days 22:01:43
# 231229  ...     48.0   1832.0       88.0  0 days 01:19:55  21 days 22:01:43
# 231230  ...     48.0   1832.0       88.0  0 days 01:19:55  21 days 22:01:43
#
#             SomaTempo718  Intervalo_SomaTempo1  Intervalo_SomaTempo2  \
# 0        0 days 10:36:04                <1 dia      1 semana - 1 mês
# 1        0 days 10:36:04                <1 dia      1 semana - 1 mês
# 2        0 days 10:36:04                <1 dia      1 semana - 1 mês
# 3        0 days 10:36:04                <1 dia      1 semana - 1 mês
# 4        0 days 10:36:04                <1 dia      1 semana - 1 mês
# ...                  ...                   ...                   ...
# 218462  37 days 16:08:26                <1 dia       1 mês - 3 meses
# 231227  13 days 01:04:31                <1 dia      1 semana - 1 mês
# 231228  13 days 01:04:31                <1 dia      1 semana - 1 mês
# 231229  13 days 01:04:31                <1 dia      1 semana - 1 mês
# 231230  13 days 01:04:31                <1 dia      1 semana - 1 mês
#
#        Intervalo_SomaTempo718 TemFalhaRod
# 0                      <1 dia         0.0
# 1                      <1 dia         0.0
# 2                      <1 dia         0.0
# 3                      <1 dia         0.0
# 4                      <1 dia         0.0
# ...                       ...         ...
# 218462        1 mês - 3 meses         0.0
# 231227       1 semana - 1 mês         0.0
# 231228       1 semana - 1 mês         0.0
# 231229       1 semana - 1 mês         0.0
# 231230       1 semana - 1 mês         0.0
#
# [130136 rows x 25 columns]

# %%
df_merged.columns
# Out:
# Index(['index', 'KNR', 'STATUS', 'DATA', 'TempoR750', 'TempoL540', 'TempoG700',
#        'TempoM600', 'TempoM700', 'R750', 'L540', 'G700', 'M600', 'M700',
#        'Nvezes1', 'Nvezes2', 'Nvezes718', 'FALHAS'],
#       dtype='object')

# %%
df_merged = df_merged.drop(columns=['index', 'Nvezes1', 'Nvezes2', 'Nvezes718'])

# %%
df_merged.head()
# Out:
#             KNR STATUS                 DATA        TempoR750        TempoL540  \
# 0  2023-4026002   R750  2023-09-29 08:16:23  3 days 01:04:05  0 days 00:00:00
# 1  2023-4026002   L540  2023-10-02 09:20:28  0 days 00:00:00  1 days 01:25:34
# 2  2023-4026002   G700  2023-10-03 10:46:02  0 days 00:00:00  0 days 00:00:00
# 3  2023-4026002   M600  2023-10-03 12:21:54  0 days 00:00:00  0 days 00:00:00
# 4  2023-4026002   M700  2023-10-03 13:31:36  0 days 00:00:00  0 days 00:00:00
#
#          TempoG700        TempoM600 TempoM700  R750  L540  G700  M600  M700  \
# 0  0 days 00:00:00  0 days 00:00:00    0 days     1     1     1     1     1
# 1  0 days 00:00:00  0 days 00:00:00    0 days     1     1     1     1     1
# 2  0 days 01:35:52  0 days 00:00:00    0 days     1     1     1     1     1
# 3  0 days 00:00:00  0 days 01:09:42    0 days     1     1     1     1     1
# 4  0 days 00:00:00  0 days 00:00:00    0 days     1     1     1     1     1
#
#    FALHAS
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_merged.to_csv('df_completoV3.csv', index=False)

# %% [markdown]
# # ATÉ AQUI TA CERTO, DPS É O BALANCEAMENTO QUE AINDA NÃO TESTEI

# %%
# %pip install tensorflow==2.13.0
# %pip install scikit-learn==1.3.0
# Out:
# Requirement already satisfied: tensorflow==2.13.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: six>=1.12.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (4.25.4)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (18.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (0.37.1)
# Requirement already satisfied: packaging in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (24.1)
# Requirement already satisfied: h5py>=2.9.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (3.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (1.66.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (2.1.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (24.3.25)
# Requirement already satisfied: setuptools in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorflow==2.13.0) (59.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.13.0) (0.44.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.32.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.3.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn==1.3.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from scikit-learn==1.3.0) (1.24.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from scikit-learn==1.3.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from scikit-learn==1.3.0) (3.5.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/linguica/rodrigo/EstudoDados/venv/lib/python3.10/site-packages (from scikit-learn==1.3.0) (1.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
df_falhas.head()
# Out:
#    Unnamed: 0           KNR   MODELO   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 0           0  2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521   ZP5
# 1           1  2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521   ZP5
# 2           2  2023-4130482  AUDI Q3  2Y2Y   DSN  PCEQS999  2054701  ESPC
# 3           3  2023-4130482  AUDI Q3  2Y2Y   DSN  PCEQS999  2054701  ESPC
# 4           4  2023-4130664  AUDI Q3  6Y6Y   DSN  PCEQS805  7000240  ZP82
#
#                                            FALHA                        DATA
# 0                 Porta dianteira Folga (Ajuste)  2023-01-09 22:24:44.272000
# 1                  Porta traseira Folga (Ajuste)  2023-01-09 22:25:02.960000
# 2                   Lanterna tras (09) Interfere  2023-01-10 09:18:25.238000
# 3  Emblema / logo - Adesivos em geral Solto(a) ¨  2023-01-10 09:18:40.728000
# 4                  Painel instrumentos Ruído (-)  2023-01-10 11:17:56.489000

# %%
df_falhas = df_falhas.drop(columns=['Unnamed: 0', 'MODELO',	'COR', 'MOTOR',	'ESTACAO', 'USUARIO', 'HALLE', 'FALHA', 'DATA'])

# %%
df_falhas
# Out:
#                  KNR
# 0       2023-1326197
# 1       2023-1326197
# 2       2023-4130482
# 3       2023-4130482
# 4       2023-4130664
# ...              ...
# 663814  2024-1336453
# 663815  2024-1336485
# 663816  2024-1346004
# 663817  2024-1336453
# 663818  2024-1336485
#
# [663819 rows x 1 columns]

# %%
# Criar um conjunto dos KNRs presentes em df_falha
knr_falha_set = set(df_falhas['KNR'])

# Criar uma nova coluna em df_status que verifica se o KNR está em df_falha
df_merged['FALHAS'] = df_merged['KNR'].apply(lambda knr: 1 if knr in knr_falha_set else 0)

# Exibir as primeiras linhas do DataFrame resultante para conferir
df_merged.head()
# Out:
#      index           KNR STATUS                 DATA        TempoR750  \
# 0  1048577  2023-4026002   R750  2023-09-29 08:16:23  3 days 01:04:05
# 1  1048592  2023-4026002   L540  2023-10-02 09:20:28  0 days 00:00:00
# 2  1048611  2023-4026002   G700  2023-10-03 10:46:02  0 days 00:00:00
# 3  1048613  2023-4026002   M600  2023-10-03 12:21:54  0 days 00:00:00
# 4  1048617  2023-4026002   M700  2023-10-03 13:31:36  0 days 00:00:00
#
#          TempoL540        TempoG700        TempoM600 TempoM700  R750  L540  \
# 0  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1     1
# 1  1 days 01:25:34  0 days 00:00:00  0 days 00:00:00    0 days     1     1
# 2  0 days 00:00:00  0 days 01:35:52  0 days 00:00:00    0 days     1     1
# 3  0 days 00:00:00  0 days 00:00:00  0 days 01:09:42    0 days     1     1
# 4  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1     1
#
#    G700  M600  M700  Nvezes1  Nvezes2  Nvezes718  TemFalhaRod  FALHAS
# 0     1     1     1     18.0    452.0       14.0          0.0       1
# 1     1     1     1     18.0    452.0       14.0          0.0       1
# 2     1     1     1     18.0    452.0       14.0          0.0       1
# 3     1     1     1     18.0    452.0       14.0          0.0       1
# 4     1     1     1     18.0    452.0       14.0          0.0       1

# %%
df_merged = df_merged.drop(columns=['TemFalhaRod'])

# %%
df_merged
# Out:
#           index           KNR STATUS                 DATA        TempoR750  \
# 0       1048577  2023-4026002   R750  2023-09-29 08:16:23  3 days 01:04:05
# 1       1048592  2023-4026002   L540  2023-10-02 09:20:28  0 days 00:00:00
# 2       1048611  2023-4026002   G700  2023-10-03 10:46:02  0 days 00:00:00
# 3       1048613  2023-4026002   M600  2023-10-03 12:21:54  0 days 00:00:00
# 4       1048617  2023-4026002   M700  2023-10-03 13:31:36  0 days 00:00:00
# ...         ...           ...    ...                  ...              ...
# 218462  3433027  2024-1916086   M700  2024-04-05 12:05:17  0 days 00:00:00
# 231227  3578556  2024-2016184   R750  2024-03-21 17:53:25  0 days 00:00:00
# 231228  3578595  2024-2016184   G700  2024-04-10 14:15:40  0 days 00:00:00
# 231229  3578600  2024-2016184   M600  2024-04-15 11:48:32  0 days 00:00:00
# 231230  3578602  2024-2016184   M700  2024-04-15 11:48:33  0 days 00:00:00
#
#               TempoL540        TempoG700        TempoM600 TempoM700  R750  \
# 0       0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# 1       1 days 01:25:34  0 days 00:00:00  0 days 00:00:00    0 days     1
# 2       0 days 00:00:00  0 days 01:35:52  0 days 00:00:00    0 days     1
# 3       0 days 00:00:00  0 days 00:00:00  0 days 01:09:42    0 days     1
# 4       0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# ...                 ...              ...              ...       ...   ...
# 218462  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# 231227  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
# 231228  0 days 00:00:00  4 days 21:32:52  0 days 00:00:00    0 days     1
# 231229  0 days 00:00:00  0 days 00:00:00  0 days 00:00:01    0 days     1
# 231230  0 days 00:00:00  0 days 00:00:00  0 days 00:00:00    0 days     1
#
#         L540  G700  M600  M700  Nvezes1  Nvezes2  Nvezes718  FALHAS
# 0          1     1     1     1     18.0    452.0       14.0       1
# 1          1     1     1     1     18.0    452.0       14.0       1
# 2          1     1     1     1     18.0    452.0       14.0       1
# 3          1     1     1     1     18.0    452.0       14.0       1
# 4          1     1     1     1     18.0    452.0       14.0       1
# ...      ...   ...   ...   ...      ...      ...        ...     ...
# 218462     0     1     1     1     54.0   2106.0      198.0       1
# 231227     0     1     1     1     48.0   1832.0       88.0       1
# 231228     0     1     1     1     48.0   1832.0       88.0       1
# 231229     0     1     1     1     48.0   1832.0       88.0       1
# 231230     0     1     1     1     48.0   1832.0       88.0       1
#
# [130136 rows x 18 columns]

# %%
# Contar o número de 1s e 0s na coluna 'KNR_in_both'
counts = df_merged['FALHAS'].value_counts()

# Exibir o resultado
print(counts)
# Out:
# FALHAS
# 1    130136
# Name: count, dtype: int64

# %%
df_merged.to_csv('df_completoV2.csv', index=False)

# %%
# import pandas as pd
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, LSTM, Dropout
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import MinMaxScaler

# %%
# from sklearn.utils import resample

# # Separar as classes majoritária (0) e minoritária (1)
# df_falha_0 = df_merged[df_merged['TemFalhaRod'] == 0.0]
# df_falha_1 = df_merged[df_merged['TemFalhaRod'] == 1.0]

# # Fazer undersampling da classe majoritária (0) para ter o mesmo tamanho da classe minoritária (1)
# df_falha_0_under = resample(df_falha_0, 
#                             replace=False,  # não fazer repetição de amostras
#                             n_samples=len(df_falha_1),  # reduzir para o tamanho da classe minoritária
#                             random_state=42)  # controlar a aleatoriedade para resultados reproduzíveis

# # Combinar as amostras balanceadas
# df_balanced = pd.concat([df_falha_0_under, df_falha_1])

# # Embaralhar as amostras para evitar que as classes fiquem em blocos
# df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# # Exibir o número de amostras de cada classe para confirmar o balanceamento
# print(df_balanced['TemFalhaRod'].value_counts())
