# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df_resultado = pd.read_csv("rod_maquina.csv",low_memory=False)

# %%
df_rod = pd.read_csv("df_rod.csv",low_memory=False)

# %%
# df_resultado.drop(df_resultado.columns[9],axis=1,inplace=True)
df_resultado.head()
# Out:
#             KNR   MODELO   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 0  2024-1346277  T-CROSS  K2K2   CWL  PCEQS709  2079860   ROD
# 1  2024-1346277  T-CROSS  K2K2   CWL  PCEQS709  2079860   ROD
# 2  2024-1346277  T-CROSS  K2K2   CWL  PCEQS709  2079860   ROD
# 3  2024-1346277  T-CROSS  K2K2   CWL  PCEQS709  2079860   ROD
# 4  2024-1346277  T-CROSS  K2K2   CWL  PCEQS709  2079860   ROD
#
#                                      FALHA             DATA_x    NAME  ID  \
# 0  Console central Ruído de corpo estranho  5/4/2024 16:50:34  012001   1
# 1  Console central Ruído de corpo estranho  5/4/2024 16:50:34  012001   1
# 2  Console central Ruído de corpo estranho  5/4/2024 16:50:34  012002   1
# 3  Console central Ruído de corpo estranho  5/4/2024 16:50:34  012002   1
# 4  Console central Ruído de corpo estranho  5/4/2024 16:50:34  012003   1
#
#    STATUS UNIT  VALUE_ID VALUE               DATA_y
# 0      10  NaN       0.0   NaN  2024-03-27 15:49:28
# 1      10  NaN       NaN   NaN  2024-03-27 15:49:28
# 2      10  NaN       0.0   NaN  2024-03-27 16:08:24
# 3      10  NaN       NaN   NaN  2024-03-27 16:08:24
# 4      10  NaN       0.0   NaN  2024-03-27 16:08:38
